# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datasets import Dataset

# %% [markdown]
# ## Load data

# %%
# phenotypes
phen_df = pd.read_csv("data/all_phenotypes.tsv", sep="\t", header=0)
# static features
static_df = pd.read_csv("data/static_features.tsv", sep="\t", header=0)
static_df.sort_values(by="participant_id",ascending=True,inplace=True)
phen_df.sort_values(by="participant_id",ascending=True,inplace=True)

# %%
print(phen_df.shape)
# Out:
# (442, 1108)

# %% [markdown]
# ## Create labels

# %%
phen_df
# Out:
#     participant_id redcap_repeat_instrument  redcap_repeat_instance  \
# 0         004d42e9              Participant                     1.0
# 1         01401050              Participant                     1.0
# 2         016023f6              Participant                     1.0
# 3         02624589              Participant                     1.0
# 4         02955d67              Participant                     1.0
# ..             ...                      ...                     ...
# 437       fc603d45              Participant                     1.0
# 438       fc61a1ff              Participant                     1.0
# 439       fe6cefa7              Participant                     1.0
# 440       ff58dff0              Participant                     1.0
# 441       ff75b163              Participant                     1.0
#
#     selected_language   age is_control_participant laryng_cancer  \
# 0             English  75.0                     No     Unchecked
# 1             English  74.0                     No     Unchecked
# 2             English  78.0                     No     Unchecked
# 3             English  82.0                     No     Unchecked
# 4             English  76.0                    Yes     Unchecked
# ..                ...   ...                    ...           ...
# 437           English  81.0                     No     Unchecked
# 438           English  72.0                     No     Unchecked
# 439           English  50.0                     No     Unchecked
# 440           English  21.0                    Yes     Unchecked
# 441           English  69.0                     No     Unchecked
#
#     benign_cord_lesion        rrp   spas_dys  ... vocabulary_item_word_6  \
# 0            Unchecked  Unchecked  Unchecked  ...            affirmation
# 1            Unchecked  Unchecked  Unchecked  ...                surreal
# 2            Unchecked  Unchecked    Checked  ...                    NaN
# 3            Unchecked  Unchecked    Checked  ...                    NaN
# 4            Unchecked  Unchecked  Unchecked  ...                    NaN
# ..                 ...        ...        ...  ...                    ...
# 437          Unchecked  Unchecked  Unchecked  ...       compartmentalize
# 438          Unchecked  Unchecked  Unchecked  ...                    NaN
# 439          Unchecked  Unchecked  Unchecked  ...                    NaN
# 440          Unchecked  Unchecked  Unchecked  ...              aquaplane
# 441            Checked  Unchecked  Unchecked  ...                    NaN
#
#     vocabulary_item_difficulty_6 random_session_id  \
# 0                            3.0          07031CC3
# 1                            3.0          09E64686
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# ..                           ...               ...
# 437                          3.0          CD772E40
# 438                          NaN               NaN
# 439                          NaN               NaN
# 440                          3.0          A5484A20
# 441                          NaN               NaN
#
#         random_recording_acoustic_task_id random_duration  \
# 0    A91D679E-201E-49AF-AD3D-D988836B3BCC            83.0
# 1    AAC88E40-7F5C-40D6-BA68-93A01923E467           192.0
# 2                                     NaN             NaN
# 3                                     NaN             NaN
# 4                                     NaN             NaN
# ..                                    ...             ...
# 437  A8ABD411-49FB-4FAE-8E58-445A1A3BE711            64.0
# 438                                   NaN             NaN
# 439                                   NaN             NaN
# 440  0598F4BC-52E6-4302-8EF7-F3C9AA6097DE            50.0
# 441                                   NaN             NaN
#
#      random_item_generation_category Voice Disorders  \
# 0    English words starting with 't'           False
# 1                            Letters           False
# 2                                NaN            True
# 3                                NaN            True
# 4                                NaN            True
# ..                               ...             ...
# 437                          Animals           False
# 438                              NaN            True
# 439                              NaN            True
# 440                          Numbers            True
# 441                              NaN            True
#
#     Neurological and Neurodegenerative Disorders  \
# 0                                           True
# 1                                           True
# 2                                          False
# 3                                          False
# 4                                           True
# ..                                           ...
# 437                                         True
# 438                                        False
# 439                                        False
# 440                                         True
# 441                                        False
#
#     Mood and Psychiatric Disorders Respiratory Disorders
# 0                             True                 False
# 1                             True                 False
# 2                            False                 False
# 3                            False                 False
# 4                             True                  True
# ..                             ...                   ...
# 437                          False                 False
# 438                          False                  True
# 439                          False                  True
# 440                           True                  True
# 441                          False                 False
#
# [442 rows x 1108 columns]

# %%
phen_df["Voice Disorders"].value_counts()
# Out:
# Voice Disorders
# True     230
# False    212
# Name: count, dtype: int64

# %%
static_df["Voice Disorders"] = [int(phen_df[phen_df["participant_id"] == row.participant_id]["Voice Disorders"].tolist()[0]) for idx,row in static_df.iterrows()]

# %%
static_df
# Out:
#       participant_id session_id                  task_name  \
# 0           004d42e9   07031CC3             Animal-fluency
# 26          004d42e9   07031CC3    Productive-Vocabulary-1
# 27          004d42e9   07031CC3    Productive-Vocabulary-2
# 28          004d42e9   07031CC3    Productive-Vocabulary-3
# 29          004d42e9   07031CC3    Productive-Vocabulary-4
# ...              ...        ...                        ...
# 19245       ff75b163   6A3E7090         Diadochokinesis-TA
# 19246       ff75b163   6A3E7090  Diadochokinesis-buttercup
# 19247       ff75b163   6A3E7090                Free-Speech
# 19249       ff75b163   6A3E7090              Free-speech-2
# 19270       ff75b163   6A3E7090               Story-recall
#
#                                            transcription  \
# 0      Dogs, cats, lions, panthers, leopards, elephan...
# 26     broccoli broccoli is a green vegetable and hea...
# 27     Capitalization. Hmm. Could be, um, when you're...
# 28     Unsuitable. Not correct. Or... I said not corr...
# 29               Minority. Minority is the lesser group.
# ...                                                  ...
# 19245                   Ta ta ta ta ta ta ta ta ta ta ta
# 19246  Markup, markup, markup, markup, markup, markup...
# 19247  I came to the physician because I had a feelin...
# 19249                                                NaN
# 19270  Grandfather was about 93 years old. He had a l...
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              30.849073
# 26                             34.447186
# 27                             35.895359
# 28                             35.248405
# 29                             33.798946
# ...                                  ...
# 19245                          26.530842
# 19246                          27.925495
# 19247                          25.366678
# 19249                          26.703327
# 19270                          25.704922
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                    0.205649
# 26                                   0.057132
# 27                                   0.092448
# 28                                   0.101374
# 29                                   0.114689
# ...                                       ...
# 19245                                0.038758
# 19246                                0.054326
# 19247                                0.090976
# 19249                                0.166226
# 19270                                0.102639
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       26.938833
# 26                                      32.960548
# 27                                      33.253757
# 28                                      33.987968
# 29                                      32.843185
# ...                                           ...
# 19245                                   25.860199
# 19246                                   27.288794
# 19247                                   23.924431
# 19249                                   24.957359
# 19270                                   24.731934
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       32.299248
# 26                                      33.506256
# 27                                      35.642937
# 28                                      36.224056
# 29                                      34.022396
# ...                                           ...
# 19245                                   26.675362
# 19246                                   28.198372
# 19247                                   25.256680
# 19249                                   26.008017
# 19270                                   26.023228
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       36.319099
# 26                                      36.057877
# 27                                      37.830379
# 28                                      37.653236
# 29                                      36.028976
# ...                                           ...
# 19245                                   27.344505
# 19246                                   28.900181
# 19247                                   26.426678
# 19249                                   27.915869
# 19270                                   27.229540
#
#        F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  ...  local_shimmer  \
# 0                                      9.380266  ...       0.140185
# 26                                     3.097328  ...       0.081463
# 27                                     4.576622  ...       0.105887
# 28                                     3.665268  ...       0.111295
# 29                                     3.185791  ...       0.119717
# ...                                         ...  ...            ...
# 19245                                  1.484306  ...       0.093277
# 19246                                  1.611387  ...       0.172056
# 19247                                  2.502247  ...       0.099615
# 19249                                  2.958509  ...       0.122538
# 19270                                  2.497606  ...       0.110311
#
#        localDB_shimmer  apq3_shimmer  apq5_shimmer  apq11_shimmer  \
# 0             1.279872      0.062109      0.065476       0.063903
# 26            0.909085      0.037340      0.037903       0.054074
# 27            1.090807      0.052075      0.067322       0.076049
# 28            1.158668      0.050776      0.061889       0.081749
# 29            1.170932      0.056202      0.063807       0.061901
# ...                ...           ...           ...            ...
# 19245         0.994439      0.029967      0.051134       0.088584
# 19246         1.558691      0.075453      0.125921       0.179042
# 19247         1.020855      0.036914      0.055092       0.096946
# 19249         1.161885      0.044590      0.064484       0.138375
# 19270         1.091564      0.039070      0.062255       0.114856
#
#        dda_shimmer      stoi      pesq     si_sdr  Voice Disorders
# 0         0.186326  0.594471  1.159233 -14.364435                0
# 26        0.112019  0.802794  1.277508  -0.301972                0
# 27        0.156226  0.742845  1.199748  -1.893810                0
# 28        0.152328  0.705393  1.185849  -3.215629                0
# 29        0.168605  0.818446  1.240876  -1.725452                0
# ...            ...       ...       ...        ...              ...
# 19245     0.089901  0.993067  3.620620  25.058619                1
# 19246     0.226358  0.943791  2.379631  17.349405                1
# 19247     0.110742  0.898831  1.960933  12.243779                1
# 19249     0.133770  0.869760  1.683203   6.723745                1
# 19270     0.117209  0.771001  1.544471   5.902566                1
#
# [19271 rows x 136 columns]

# %%
y = static_df["Voice Disorders"].copy()
X = static_df.copy().drop(columns=["participant_id", "session_id","task_name","transcription","Voice Disorders"])
print(X.shape, y.shape)
# Out:
# (19271, 131) (19271,)

# %% [markdown]
# ## Calculate group numbers

# %%
# calculate group numbers
all_groups = np.array(static_df["participant_id"].tolist())
uniq_groups = static_df["participant_id"].unique()
static_df["participant_id_int"] = [np.where(uniq_groups==row.participant_id)[0][0] for idx,row in static_df.iterrows()]
static_df[["participant_id_int","participant_id"]]
# Out:
#        participant_id_int participant_id
# 0                       0       004d42e9
# 26                      0       004d42e9
# 27                      0       004d42e9
# 28                      0       004d42e9
# 29                      0       004d42e9
# ...                   ...            ...
# 19245                 441       ff75b163
# 19246                 441       ff75b163
# 19247                 441       ff75b163
# 19249                 441       ff75b163
# 19270                 441       ff75b163
#
# [19271 rows x 2 columns]

# %%
groups = static_df["participant_id_int"].copy()
groups
# Out:
# 0          0
# 26         0
# 27         0
# 28         0
# 29         0
#         ...
# 19245    441
# 19246    441
# 19247    441
# 19249    441
# 19270    441
# Name: participant_id_int, Length: 19271, dtype: int64

# %% [markdown]
# ## Drop NaNs

# %% [markdown]
# #### Drop columns with NaNs over some threshold

# %%
# drop nans
nans = X.isna().sum()
thresh_nans = nans[nans>50]
print(len(thresh_nans))
# Out:
# 35

# %%
thresh_nans
# Out:
# speaking_rate                      83
# articulation_rate                  83
# phonation_ratio                    83
# pause_rate                         83
# mean_pause_duration                83
# mean_f0_hertz                     443
# std_f0_hertz                      522
# mean_hnr_db                        79
# spectral_slope                    538
# spectral_tilt                     538
# cepstral_peak_prominence_mean     751
# cepstral_peak_prominence_std      751
# mean_f1_loc                       166
# std_f1_loc                        166
# mean_b1_loc                       166
# std_b1_loc                        166
# mean_f2_loc                       166
# std_f2_loc                        166
# mean_b2_loc                       166
# std_b2_loc                        166
# spectral_gravity                  453
# spectral_std_dev                  453
# spectral_skewness                 453
# spectral_kurtosis                 453
# local_jitter                      538
# localabsolute_jitter              538
# rap_jitter                        641
# ppq5_jitter                      1021
# ddp_jitter                        641
# local_shimmer                     693
# localDB_shimmer                   693
# apq3_shimmer                      937
# apq5_shimmer                     1501
# apq11_shimmer                    3203
# dda_shimmer                       937
# dtype: int64

# %%
X.drop(columns=thresh_nans.index,inplace=True)
print(X.shape)
# Out:
# (19271, 96)

# %% [markdown]
# #### Drop rows with NaNs under threshold

# %%
nans = X.isna().sum()
nans[nans>0]
# Out:
# std_intensity_db     2
# std_hnr_db          14
# stoi                17
# pesq                17
# si_sdr              17
# dtype: int64

# %%
# drop rows
inds_to_drop = []
inds_to_drop.extend(X[X["std_intensity_db"].isna()].index)
inds_to_drop.extend(X[X["std_hnr_db"].isna()].index)
inds_to_drop.extend(X[X["stoi"].isna()].index)
inds_to_drop.extend(X[X["pesq"].isna()].index)
inds_to_drop.extend(X[X["si_sdr"].isna()].index)
print(len(inds_to_drop))
# Out:
# 67

# %%
X.drop(index=inds_to_drop,inplace=True)
y.drop(index=inds_to_drop,inplace=True)
groups.drop(index=inds_to_drop,inplace=True)
print(X.shape, y.shape, groups.shape)
# Out:
# (19238, 96) (19238,) (19238,)

# %%
X = X.to_numpy()
y = y.to_numpy()
groups = groups.to_numpy()
print(X.shape, y.shape, groups.shape)
# Out:
# (19238, 96) (19238,) (19238,)

# %%
X
# Out:
# array([[ 30.84907341,   0.20564899,  26.93883324, ...,   0.59447134,
#           1.15923345, -14.3644352 ],
#        [ 34.44718552,   0.05713191,  32.9605484 , ...,   0.80279362,
#           1.27750802,  -0.30197161],
#        [ 35.89535904,   0.09244755,  33.25375748, ...,   0.74284542,
#           1.19974804,  -1.89381027],
#        ...,
#        [ 25.36667824,   0.09097601,  23.92443085, ...,   0.89883059,
#           1.96093297,  12.24377918],
#        [ 26.70332718,   0.16622576,  24.95735931, ...,   0.86976027,
#           1.68320274,   6.72374535],
#        [ 25.70492172,   0.10263921,  24.73193359, ...,   0.77100056,
#           1.54447126,   5.90256643]], shape=(19238, 96))

# %% [markdown]
# ## Save cleaned data

# %%
import pickle

with open("data/X_clean.pkl", 'wb') as f:
    pickle.dump(X, f)
with open("data/y_clean.pkl", 'wb') as f:
    pickle.dump(y, f)
with open("data/groups.pkl", 'wb') as f:
    pickle.dump(groups, f)
